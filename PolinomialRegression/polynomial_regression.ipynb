# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv("Position_Salaries.csv")
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
regressao_linear = LinearRegression()
regressao_linear.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
regressao_polinomial = PolynomialFeatures(degree=4)
X_polinomial = regressao_polinomial.fit_transform(X)
regressao_linear2 = LinearRegression()
regressao_linear2.fit(X_polinomial, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(X, y, color='red')
plt.plot(X, regressao_linear.predict(X), color='blue')
plt.title('Verdade ou não (regressão linear)')
plt.xlabel('Nível do cargo')
plt.ylabel('Salário')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(X, y, color='red')
plt.plot(X, regressao_linear2.predict(regressao_polinomial.fit_transform(X)), color='blue')
plt.title('Verdade ou não (regressão linear)')
plt.xlabel('Nível do cargo')
plt.ylabel('Salário')
plt.show()

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
regressao_linear.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
regressao_linear2.predict(regressao_polinomial.fit_transform([[6.5]]))
# Out:
# array([158862.4526515])
